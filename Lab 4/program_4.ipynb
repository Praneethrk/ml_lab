# %%
import numpy as np

X = np.array(([2,9],[1,5],[3,6]),dtype=float)

y = np.array(([92],[86],[89]),dtype=float)

X=X/np.amax(X,axis=0)

y=y/100

def sigmoid(x):

    return 1/(1+np.exp(-x))

def derivatives_sigmoid(x):

    return x*(1-x)

epoch=20

learning_rate=0.1

inputlayer_neurons=2

hiddenlayer_neurons=3

outputlayer_neurons=1

wh=np.random.uniform(size=(inputlayer_neurons,hiddenlayer_neurons))

bh=np.random.uniform(size=(1,hiddenlayer_neurons))

wo=np.random.uniform(size=(hiddenlayer_neurons,outputlayer_neurons))

bo=np.random.uniform(size=(1,outputlayer_neurons))

for i in range(epoch):
    net_h=np.dot(X,wh)+bh
    sigma_h=sigmoid(net_h)
    net_o=np.dot(sigma_h,wo)+bo
    output=sigmoid(net_o)
    deltaK=(y-output)*derivatives_sigmoid(output)
    deltaH=deltaK.dot(wo.T)*derivatives_sigmoid(sigma_h)
    wo=wo+sigma_h.T.dot(deltaK)*learning_rate
    wh=wh+X.T.dot(deltaH)*learning_rate
    error=sum(deltaK)**2/len(deltaK)

   

    print('Epoch -> {0}, lrate -> {1}, error -> {2}'.format(i,learning_rate,error))

print("Input:\n"+str(X))

print("Actual Output:\n"+str(y))

print("Predicted Output:\n",output)
# Out:
# Epoch -> 0, lrate -> 0.1, error -> [2.57885904e-08]
# Epoch -> 1, lrate -> 0.1, error -> [2.57118607e-08]
# Epoch -> 2, lrate -> 0.1, error -> [2.56356711e-08]
# Epoch -> 3, lrate -> 0.1, error -> [2.55600174e-08]
# Epoch -> 4, lrate -> 0.1, error -> [2.54848954e-08]
# Epoch -> 5, lrate -> 0.1, error -> [2.54103009e-08]
# Epoch -> 6, lrate -> 0.1, error -> [2.53362298e-08]
# Epoch -> 7, lrate -> 0.1, error -> [2.52626781e-08]
# Epoch -> 8, lrate -> 0.1, error -> [2.51896416e-08]
# Epoch -> 9, lrate -> 0.1, error -> [2.51171164e-08]
# Epoch -> 10, lrate -> 0.1, error -> [2.50450985e-08]
# Epoch -> 11, lrate -> 0.1, error -> [2.49735839e-08]
# Epoch -> 12, lrate -> 0.1, error -> [2.49025687e-08]
# Epoch -> 13, lrate -> 0.1, error -> [2.48320491e-08]
# Epoch -> 14, lrate -> 0.1, error -> [2.47620212e-08]
# Epoch -> 15, lrate -> 0.1, error -> [2.46924812e-08]
# Epoch -> 16, lrate -> 0.1, error -> [2.46234252e-08]
# Epoch -> 17, lrate -> 0.1, error -> [2.45548497e-08]
# Epoch -> 18, lrate -> 0.1, error -> [2.44867508e-08]
# Epoch -> 19, lrate -> 0.1, error -> [2.44191248e-08]
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.89492603]
#  [0.87982708]
#  [0.89569556]]
