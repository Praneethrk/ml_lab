# %%
import numpy as np

X = np.array(([2,9],[1,5],[3,6]),dtype=float)

y = np.array(([92],[86],[89]),dtype=float)

X=X/np.amax(X,axis=0)

y=y/100

def sigmoid(x):

    return 1/(1+np.exp(-x))

def derivatives_sigmoid(x):

    return x*(1-x)

epoch=20

learning_rate=0.1

inputlayer_neurons=2

hiddenlayer_neurons=3

outputlayer_neurons=1

wh=np.random.uniform(size=(inputlayer_neurons,hiddenlayer_neurons))

bh=np.random.uniform(size=(1,hiddenlayer_neurons))

wo=np.random.uniform(size=(hiddenlayer_neurons,outputlayer_neurons))

bo=np.random.uniform(size=(1,outputlayer_neurons))

for i in range(epoch):
    net_h=np.dot(X,wh)+bh
    sigma_h=sigmoid(net_h)
    net_o=np.dot(sigma_h,wo)+bo
    output=sigmoid(net_o)
    deltaK=(y-output)*derivatives_sigmoid(output)
    deltaH=deltaK.dot(wo.T)*derivatives_sigmoid(sigma_h)
    wo=wo+sigma_h.T.dot(deltaK)*learning_rate
    wh=wh+X.T.dot(deltaH)*learning_rate
    error=sum(deltaK)**2/len(deltaK)

   

    print('Epoch -> {0}, lrate -> {1}, error -> {2}'.format(i,learning_rate,error))

print("Input:\n"+str(X))

print("Actual Output:\n"+str(y))

print("Predicted Output:\n",output)
# Out:
# Epoch -> 0, lrate -> 0.1, error -> [2.63868381e-06]
# Epoch -> 1, lrate -> 0.1, error -> [2.60397274e-06]
# Epoch -> 2, lrate -> 0.1, error -> [2.56973928e-06]
# Epoch -> 3, lrate -> 0.1, error -> [2.53597626e-06]
# Epoch -> 4, lrate -> 0.1, error -> [2.50267667e-06]
# Epoch -> 5, lrate -> 0.1, error -> [2.4698336e-06]
# Epoch -> 6, lrate -> 0.1, error -> [2.43744025e-06]
# Epoch -> 7, lrate -> 0.1, error -> [2.40548994e-06]
# Epoch -> 8, lrate -> 0.1, error -> [2.37397611e-06]
# Epoch -> 9, lrate -> 0.1, error -> [2.34289228e-06]
# Epoch -> 10, lrate -> 0.1, error -> [2.31223209e-06]
# Epoch -> 11, lrate -> 0.1, error -> [2.28198931e-06]
# Epoch -> 12, lrate -> 0.1, error -> [2.25215777e-06]
# Epoch -> 13, lrate -> 0.1, error -> [2.22273143e-06]
# Epoch -> 14, lrate -> 0.1, error -> [2.19370434e-06]
# Epoch -> 15, lrate -> 0.1, error -> [2.16507064e-06]
# Epoch -> 16, lrate -> 0.1, error -> [2.13682457e-06]
# Epoch -> 17, lrate -> 0.1, error -> [2.10896047e-06]
# Epoch -> 18, lrate -> 0.1, error -> [2.08147276e-06]
# Epoch -> 19, lrate -> 0.1, error -> [2.05435596e-06]
# Input:
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
#  [[0.88524527]
#  [0.87320367]
#  [0.88590556]]
